# %% [markdown]
# <a href="https://colab.research.google.com/github/sansahil/fun/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
plt.scatter(df["households"], df["median_income"])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
y
# Out:
# 0       344700.0
# 1       176500.0
# 2       270500.0
# 3       330000.0
# 4        81700.0
#           ...
# 2995    225000.0
# 2996    237200.0
# 2997     62000.0
# 2998    162500.0
# 2999    500001.0
# Name: median_house_value, Length: 3000, dtype: float64

# %%
y.shape
# Out:
# (3000,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#       longitude  latitude
# 1385    -122.42     37.71
# 1526    -120.63     38.75
# 849     -120.80     38.31
# 716     -121.17     37.97
# 2228    -117.31     34.41
# ...         ...       ...
# 435     -119.98     38.94
# 7       -120.65     35.48
# 779     -120.92     39.56
# 360     -122.51     38.76
# 1493    -117.48     34.10
#
# [2700 rows x 2 columns]

# %%
y_train
# Out:
# 1385    215300.0
# 1526    117500.0
# 849     123600.0
# 716     130400.0
# 2228    103400.0
#           ...
# 435      99300.0
# 7       166900.0
# 779      66600.0
# 360     132600.0
# 1493     90600.0
# Name: median_house_value, Length: 2700, dtype: float64

# %%
x_test
# Out:
#       longitude  latitude
# 1450    -117.14     32.75
# 1452    -121.78     38.68
# 1908    -119.19     34.22
# 517     -118.27     33.87
# 2660    -123.73     39.17
# ...         ...       ...
# 1440    -119.63     36.32
# 2070    -118.07     33.97
# 55      -117.99     33.93
# 2567    -120.90     35.33
# 1123    -121.96     37.55
#
# [300 rows x 2 columns]

# %%
y_test
# Out:
# 1450    162500.0
# 1452     97800.0
# 1908    219900.0
# 517     181400.0
# 2660    158800.0
#           ...
# 1440     61000.0
# 2070    156200.0
# 55      175800.0
# 2567    266300.0
# 1123    162500.0
# Name: median_house_value, Length: 300, dtype: float64

# %%
from sklearn .preprocessing import StandardScaler

# %%
scaler =StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.41617523,  0.96824628],
#        [-0.51900059,  1.45583184],
#        [-0.60420712,  1.24954564],
#        ...,
#        [-0.6643529 ,  1.83558597],
#        [-1.46128457,  1.46052016],
#        [ 1.0598263 , -0.72423819]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 1.20731037, -1.33739856],
#        [-1.12549461,  1.49404301],
#        [ 0.176653  , -0.63550663],
#        [ 0.63919192, -0.80262376],
#        [-2.10587601,  1.72800698],
#        [ 0.37775687, -0.67370483],
#        [-1.37184686,  1.07386281],
#        [-0.08980964, -0.51613726],
#        [ 0.87046137, -0.82649763],
#        [-2.2918971 ,  2.57791693],
#        [ 0.3325085 , -0.64028141],
#        [-0.10489243, -0.53046159],
#        [ 0.74477145, -0.72622736],
#        [ 0.93582013,  0.04728619],
#        [ 1.09670324, -0.77874988],
#        [ 0.65427471, -0.75487601],
#        [-1.06516344,  0.53908801],
#        [ 1.26261394, -1.24190306],
#        [ 0.57383316, -0.63550663],
#        [ 0.80007502, -0.70235348],
#        [-1.31151569,  0.88764659],
#        [ 0.52355719, -0.73100213],
#        [-0.71825926,  1.60386283],
#        [-0.66295569,  1.05953849],
#        [ 0.61908153, -0.71667781],
#        [-1.24615693,  0.97836731],
#        [-1.40201244,  1.14070966],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred =clf.predict(x_test)

# %%
y_test
# Out:
# 1450    162500.0
# 1452     97800.0
# 1908    219900.0
# 517     181400.0
# 2660    158800.0
#           ...
# 1440     61000.0
# 2070    156200.0
# 55      175800.0
# 2567    266300.0
# 1123    162500.0
# Name: median_house_value, Length: 300, dtype: float64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.05

# %%
from mlxtend.plotting import plot_decision_regions
y_train_int = y_train.astype(np.int_)

# %%
 plot_decision_regions(x_train, y_train_int.values,clf=clf, legend=2)

# %%
import pickle

# %%
pickel.dump(clf,open('model.pkl','wb'))
